# %%
import pandas as pd
from pathlib import Path

import math

import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '/afs/desy.de/user/a/axelheim/private/run_BaumBauenNotebooks')



from tb_to_csv import tabulate_metrics
from plot_fcts import curve_plot, multi_metric_bar_plot

# %%
data_name = "TSD_BsXHc_50k_each_6trees_IDs_charge"

spec = "1024_0.001_512_0.3_4"

# %%
plotname_extension = data_name + '_' + spec
nfs_path = "/nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/"

plot_path = "/afs/desy.de/user/a/axelheim/private/run_BsXHc/"


data_dir = Path((nfs_path + 'tb_logs/' + data_name + '/' + spec))
print("now processing:",data_dir)
if not data_dir.is_dir():
    print("dir not found in: ", data_dir, "\n skip dir")
    continue


csv_dir = Path((nfs_path + 'tb_csv/' + data_name + '/' + spec))
csv_dir.mkdir(parents=True, exist_ok=True)

plot_path = Path((plot_path + 'plots/' + data_name + '/' + spec))
plot_path.mkdir(parents=True, exist_ok=True)

tb_metrics = tabulate_metrics(data_dir, csv_dir)


# choosing the tb_log with the most epochs recorded
epochs = []
for i in range(len(tb_metrics)):
    epochs.append(len(tb_metrics[i]))
    print(epochs[i])

most_epochs_idx = 0
if len(tb_metrics) > 1:
    most_epochs_idx = epochs.index(max(epochs))

print(most_epochs_idx)
print(len(tb_metrics))
#if most_epochs_idx == 0:
    #continue
longest_run = tb_metrics[most_epochs_idx]
# Out:
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_512_0.3_4
# Converting run events.out.tfevents.1625923604.batchg013.desy.de.52897.0
#
# - Done
# 86
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.3_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.3_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.3_2
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.3_2
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/512_0.001_128_0.3_2
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/512_0.001_128_0.3_2
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/2048_0.001_128_0.3_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/2048_0.001_128_0.3_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.5_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.5_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.6_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/1024_0.001_128_0.6_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/4096_0.001_128_0.3_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_50k_each_6trees_IDs_charge/4096_0.001_128_0.3_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/1024_0.001_512_0.3_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/1024_0.001_512_0.3_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/1024_0.001_128_0.3_4
# Converting run events.out.tfevents.1625758185.batchg009.desy.de.30525.0
#
# - Done
# 73
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/1024_0.001_128_0.3_2
# Converting run events.out.tfevents.1625759456.batchg013.desy.de.118995.0
#
# - Done
# 151
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/512_0.001_128_0.3_2
# Converting run events.out.tfevents.1625758179.batchg011.desy.de.2420.0
#
# - Done
# 300
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/2048_0.001_128_0.3_4
# Converting run events.out.tfevents.1625835721.batchg011.desy.de.19579.0
#
# - Done
# 62
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/1024_0.001_128_0.5_4
# Converting run events.out.tfevents.1625835719.batchg012.desy.de.72197.0
#
# - Done
# 151
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/1024_0.001_128_0.6_4
# Converting run events.out.tfevents.1625844235.batchg010.desy.de.117859.0
#
# - Done
# 201
# 0
# 1
# /afs/desy.de/user/a/axelheim/private/run_BaumBauenNotebooks/plot_fcts.py:78: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   name=plt.figure()#figsize=(3.487,3.487/1.618))
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_IDs_charge/4096_0.001_128_0.3_4
# Converting run events.out.tfevents.1625844248.batchg010.desy.de.117858.0
#
# - Done
# 17
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_512_0.3_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_512_0.3_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_128_0.3_4
# Converting run events.out.tfevents.1625840954.naf-belle-gpu01.desy.de.144980.0
#
# Run events.out.tfevents.1625840954.naf-belle-gpu01.desy.de.144980.0 is empty, didn't process it
#
# Converting run events.out.tfevents.1625840584.naf-belle-gpu01.desy.de.144382.0
#
# Run events.out.tfevents.1625840584.naf-belle-gpu01.desy.de.144382.0 is empty, didn't process it
#
# Converting run events.out.tfevents.1625835719.batchg013.desy.de.146655.0
#
# - Done
# 151
# 0
# 1
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_128_0.3_2
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_128_0.3_2
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/512_0.001_128_0.3_2
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/512_0.001_128_0.3_2
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/2048_0.001_128_0.3_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/2048_0.001_128_0.3_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_128_0.5_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_128_0.5_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_128_0.6_4
# dir not found in:  /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/1024_0.001_128_0.6_4
#  skip dir
# now processing: /nfs/dust/belle2/user/axelheim/BranchSeparator/run_BsXHc/tb_logs/TSD_BsXHc_15k_each_6trees_only4mom/4096_0.001_128_0.3_4
# Converting run events.out.tfevents.1625834701.naf-belle-gpu01.desy.de.130801.0
#
# Run events.out.tfevents.1625834701.naf-belle-gpu01.desy.de.130801.0 is empty, didn't process it
#
# 0
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-c3bdc547d5f5> in <module>
#      38         #if most_epochs_idx == 0:
#      39             #continue
# ---> 40         longest_run = tb_metrics[most_epochs_idx]
#      41
#      42
#
# IndexError: list index out of range

# %%
# the actual plots
# bar plot
steps = math.ceil(len(longest_run)/10)
steps = int(math.ceil(steps / 5.0)) * 5
multi_metric_bar_plot(longest_run, plot_path, ('barplot_metrics_' + plotname_extension), data_type="Validation", step=steps, metric_type="SA", title=plotname_extension)


# loss plot
loss_tr = longest_run['Cross Entropy/Training']
loss_val = longest_run['Cross Entropy/Validation']
curve_plot(loss_tr, loss_val, plot_path, ('loss_comparison_' + plotname_extension), 'Cross_Entropy', ('Loss / ' + plotname_extension))

# perfect SA plot
pLCA_tr = longest_run['PerfectSA/Training']
pLCA_val = longest_run['PerfectSA/Validation']
curve_plot(pLCA_tr, pLCA_val, plot_path, ('perfectSA_comparison_' + plotname_extension), 'PerfectSA', ('PerfectSA / ' + plotname_extension))
